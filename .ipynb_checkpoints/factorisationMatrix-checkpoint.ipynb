# %%
# Ignore  the warnings
import warnings
warnings.filterwarnings('always')
warnings.filterwarnings('ignore')

# data visualisation and manipulation
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import style
import seaborn as sns

# encodage des mots en Int
from numpy import array
from numpy import argmax
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder
 
#configure
# sets matplotlib to inline and displays graphs below the corressponding cell.
# %matplotlib inline  
style.use('fivethirtyeight')
sns.set(style='whitegrid',color_codes=True)

#model selection
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from sklearn.metrics import accuracy_score,precision_score,recall_score,confusion_matrix,roc_curve,roc_auc_score
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import LabelEncoder

#preprocess.
from keras.preprocessing.image import ImageDataGenerator

#dl libraraies
import keras
from keras import backend as K
from keras.models import Sequential
from keras.layers import Dense , merge
from keras.optimizers import Adam,SGD,Adagrad,Adadelta,RMSprop
from keras.utils import to_categorical
from keras.utils.vis_utils import model_to_dot
from keras.callbacks import ReduceLROnPlateau


from keras.layers.merge import dot
from keras.models import Model


# specifically for deeplearning.
from keras.layers import Dropout, Flatten,Activation,Input,Embedding
from keras.layers import Conv2D, MaxPooling2D, BatchNormalization
import tensorflow as tf
import random as rn
from IPython.display import SVG
 
# specifically for manipulating zipped images and getting numpy arrays of pixel values of images.
#import cv2 # erreur import
import numpy as np  
from tqdm import tqdm
import os                   
from random import shuffle  
from zipfile import ZipFile
from PIL import Image

#TL pecific modules
from keras.applications.vgg16 import VGG16

# pour parser le fichier train.json
import json
# Out:
# Using TensorFlow backend.

# %%
with open('../input/whats-cooking/train.json', 'r') as f:
    datas = json.load(f) # id, cuisine, ingredients[]

csv = []
occurence = dict()
for data in datas:
    for ingredient in data['ingredients']:
        cuisine = data['cuisine']
        
        # Ajout de la ligne id-cuisine-ingredient
        tmp = dict()
        tmp['id'] = str(data['id'])
        tmp['cuisine'] = cuisine
        tmp['ingredient'] = ingredient
        csv.append(tmp)
        
        # Comptage de l'occurence
        if not cuisine in occurence:
            occurence[cuisine] = dict()
        if not ingredient in occurence[cuisine]:
            occurence[cuisine][ingredient] = 0
        occurence[cuisine][ingredient] += 1

# Ajout des occurences dans le CSV
for ligne in csv:
    cuisine = ligne['cuisine']
    ingredient = ligne['ingredient']
    ligne['occurence'] = occurence[cuisine][ingredient]


# $ingredients contient tous les ingredients possibles


train = pd.DataFrame(csv)

# %%
df = train.copy()

# %%
df.head()
# Out:
#       id cuisine       ingredient  occurence
# 0  10259   greek  romaine lettuce         39
# 1  10259   greek     black olives         31
# 2  10259   greek   grape tomatoes         26
# 3  10259   greek           garlic        216
# 4  10259   greek           pepper        203

# %%
# Encodage des valeurs

#le_cuisine = LabelEncoder()
#le_ingredient = LabelEncoder()

#df['cuisine'] = le_cuisine.fit_transform(df['cuisine'])
#df['ingredient'] = le_ingredient.fit_transform(df['ingredient'])

# Pour inverser l'encodage il faudra utiliser ces deux lignes :
#df['cuisine'] = le_cuisine.inverse_transform(df['cuisine'])
#df['ingredient'] = le_ingredient.inverse_transform(df['ingredient'])

#df.head()

# %%
df['cuisine'].unique()

# %%
len(df['cuisine'].unique())
# Out:
# 20

# %%
df['ingredient'].unique()

# %%
len(df['ingredient'].unique())

# %%
# Pour verifier que toutes les donnees sont bonnes
df['cuisine'].isnull().sum()

# %%
# Pour verifier que toutes les donnees sont bonnes
df['ingredient'].isnull().sum()

# %%
# Creation de la matrix

index = list(df['cuisine'].unique())
columns = list(df['ingredient'].unique())
index = sorted(index)
columns = sorted(columns)
 
util_df = pd.pivot_table(data = df, values = 'occurence', index = 'cuisine', columns = 'ingredient')

# %%
util_df
# Out:
# ingredient    (    oz.) tomato sauce  (   oz.) tomato paste  \
# cuisine
# brazilian                        NaN                    NaN
# british                          NaN                    NaN
# cajun_creole                     1.0                    NaN
# chinese                          NaN                    NaN
# filipino                         NaN                    NaN
# french                           1.0                    NaN
# greek                            NaN                    NaN
# indian                           NaN                    2.0
# irish                            NaN                    NaN
# italian                          7.0                    4.0
# jamaican                         NaN                    NaN
# japanese                         NaN                    NaN
# korean                           NaN                    NaN
# mexican                          1.0                    3.0
# moroccan                         NaN                    NaN
# russian                          NaN                    NaN
# southern_us                      NaN                    NaN
# spanish                          NaN                    NaN
# thai                             1.0                    NaN
# vietnamese                       NaN                    NaN
#
# ingredient    (10 oz.) frozen chopped spinach  \
# cuisine
# brazilian                                 NaN
# british                                   NaN
# cajun_creole                              NaN
# chinese                                   NaN
# filipino                                  NaN
# french                                    NaN
# greek                                     NaN
# indian                                    NaN
# irish                                     NaN
# italian                                   3.0
# jamaican                                  NaN
# japanese                                  NaN
# korean                                    NaN
# mexican                                   NaN
# moroccan                                  NaN
# russian                                   NaN
# southern_us                               NaN
# spanish                                   NaN
# thai                                      NaN
# vietnamese                                NaN
#
# ingredient    (10 oz.) frozen chopped spinach, thawed and squeezed dry  \
# cuisine
# brazilian                                                   NaN
# british                                                     NaN
# cajun_creole                                                NaN
# chinese                                                     NaN
# filipino                                                    NaN
# french                                                      NaN
# greek                                                       1.0
# indian                                                      NaN
# irish                                                       NaN
# italian                                                     NaN
# jamaican                                                    NaN
# japanese                                                    NaN
# korean                                                      NaN
# mexican                                                     1.0
# moroccan                                                    NaN
# russian                                                     NaN
# southern_us                                                 NaN
# spanish                                                     NaN
# thai                                                        NaN
# vietnamese                                                  NaN
#
# ingredient    (14 oz.) sweetened condensed milk  (14.5 oz.) diced tomatoes  \
# cuisine
# brazilian                                   NaN                        NaN
# british                                     NaN                        NaN
# cajun_creole                                NaN                        NaN
# chinese                                     NaN                        NaN
# filipino                                    NaN                        NaN
# french                                      NaN                        NaN
# greek                                       NaN                        NaN
# indian                                      1.0                        NaN
# irish                                       NaN                        NaN
# italian                                     NaN                        1.0
# jamaican                                    NaN                        NaN
# japanese                                    NaN                        NaN
# korean                                      NaN                        NaN
# mexican                                     1.0                        2.0
# moroccan                                    NaN                        NaN
# russian                                     NaN                        NaN
# southern_us                                 NaN                        NaN
# spanish                                     NaN                        NaN
# thai                                        NaN                        NaN
# vietnamese                                  NaN                        NaN
#
# ingredient    (15 oz.) refried beans  1% low-fat buttermilk  \
# cuisine
# brazilian                        NaN                    NaN
# british                          NaN                    NaN
# cajun_creole                     NaN                    NaN
# chinese                          NaN                    NaN
# filipino                         NaN                    NaN
# french                           NaN                    NaN
# greek                            NaN                    NaN
# indian                           NaN                    NaN
# irish                            NaN                    2.0
# italian                          NaN                    1.0
# jamaican                         NaN                    NaN
# japanese                         NaN                    NaN
# korean                           NaN                    NaN
# mexican                          3.0                    NaN
# moroccan                         NaN                    NaN
# russian                          NaN                    NaN
# southern_us                      NaN                    1.0
# spanish                          NaN                    NaN
# thai                             NaN                    NaN
# vietnamese                       NaN                    NaN
#
# ingredient    1% low-fat chocolate milk  1% low-fat cottage cheese  ...  \
# cuisine                                                             ...
# brazilian                           NaN                        NaN  ...
# british                             NaN                        NaN  ...
# cajun_creole                        NaN                        NaN  ...
# chinese                             NaN                        NaN  ...
# filipino                            NaN                        NaN  ...
# french                              1.0                        1.0  ...
# greek                               NaN                        NaN  ...
# indian                              NaN                        NaN  ...
# irish                               NaN                        NaN  ...
# italian                             NaN                       10.0  ...
# jamaican                            NaN                        NaN  ...
# japanese                            NaN                        NaN  ...
# korean                              NaN                        NaN  ...
# mexican                             NaN                        NaN  ...
# moroccan                            NaN                        NaN  ...
# russian                             NaN                        NaN  ...
# southern_us                         1.0                        1.0  ...
# spanish                             NaN                        NaN  ...
# thai                                NaN                        NaN  ...
# vietnamese                          NaN                        NaN  ...
#
# ingredient    yukon gold potatoes  yuzu  yuzu juice  za'atar  zest  \
# cuisine
# brazilian                     1.0   NaN         NaN      NaN   NaN
# british                       8.0   NaN         NaN      NaN   NaN
# cajun_creole                  1.0   NaN         NaN      NaN   NaN
# chinese                       NaN   NaN         NaN      NaN   1.0
# filipino                      2.0   NaN         NaN      NaN   NaN
# french                       41.0   NaN         NaN      NaN   NaN
# greek                         4.0   NaN         NaN      NaN   2.0
# indian                       27.0   NaN         NaN      NaN   NaN
# irish                        24.0   NaN         NaN      NaN   NaN
# italian                      39.0   NaN         NaN      1.0   2.0
# jamaican                      2.0   NaN         NaN      NaN   NaN
# japanese                      6.0   5.0         3.0      NaN   1.0
# korean                        NaN   NaN         NaN      NaN   NaN
# mexican                      13.0   NaN         NaN      1.0   2.0
# moroccan                     10.0   NaN         NaN      NaN   NaN
# russian                       6.0   NaN         NaN      NaN   NaN
# southern_us                   8.0   NaN         NaN      NaN   2.0
# spanish                      21.0   NaN         NaN      NaN   NaN
# thai                          4.0   NaN         NaN      NaN   NaN
# vietnamese                    1.0   NaN         NaN      NaN   NaN
#
# ingredient    zesty italian dressing  zinfandel  ziti  zucchini  \
# cuisine
# brazilian                        NaN        NaN   NaN       3.0
# british                          NaN        NaN   NaN       3.0
# cajun_creole                     NaN        NaN   NaN      13.0
# chinese                          NaN        NaN   NaN      30.0
# filipino                         NaN        NaN   NaN       6.0
# french                           NaN        5.0   NaN      86.0
# greek                            1.0        2.0   3.0      47.0
# indian                           NaN        NaN   NaN      42.0
# irish                            NaN        NaN   NaN       4.0
# italian                         11.0        1.0  26.0     326.0
# jamaican                         NaN        NaN   NaN       5.0
# japanese                         NaN        NaN   NaN      17.0
# korean                           NaN        NaN   NaN      51.0
# mexican                          4.0        NaN   NaN     140.0
# moroccan                         NaN        NaN   NaN      40.0
# russian                          NaN        NaN   NaN       1.0
# southern_us                      1.0        NaN   NaN      14.0
# spanish                          NaN        2.0   NaN      17.0
# thai                             NaN        NaN   NaN      44.0
# vietnamese                       NaN        NaN   NaN       3.0
#
# ingredient    zucchini blossoms
# cuisine
# brazilian                   NaN
# british                     NaN
# cajun_creole                NaN
# chinese                     NaN
# filipino                    NaN
# french                      NaN
# greek                       NaN
# indian                      NaN
# irish                       NaN
# italian                     1.0
# jamaican                    NaN
# japanese                    NaN
# korean                      NaN
# mexican                     1.0
# moroccan                    NaN
# russian                     NaN
# southern_us                 NaN
# spanish                     NaN
# thai                        NaN
# vietnamese                  NaN
#
# [20 rows x 6714 columns]

# %%
util_df = util_df.fillna(0)

# %%
#X = np.array([[1, 1], [2, 1], [3, 1.2], [4, 1], [5, 0.8], [6, 1]])
X = util_df
from sklearn.decomposition import NMF
model = NMF(n_components=2, init='random', random_state=0)
W = model.fit_transform(X)
H = model.components_

# %%
print(W)
print(len(W), len(W[0]))
# Out:
# [[ 0.25861121  0.58085159]
#  [ 0.13238621  1.61153323]
#  [ 0.81031534  2.87846476]
#  [ 2.0403599   1.48667072]
#  [ 0.60869855  0.91418252]
#  [ 0.10120908  6.29224064]
#  [ 0.20558513  2.88698735]
#  [ 3.56234636  1.55085553]
#  [ 0.14207163  1.36574611]
#  [ 0.         21.91773592]
#  [ 0.4312188   0.72751495]
#  [ 0.79067905  0.76283801]
#  [ 0.65158201  0.53385564]
#  [ 7.96960878  0.        ]
#  [ 0.57639004  1.48505349]
#  [ 0.19524352  0.95633462]
#  [ 1.03692007  8.48430281]
#  [ 0.29028605  2.21649753]
#  [ 1.29180602  0.28222918]
#  [ 0.66644867  0.43327124]]
# 20 2

# %%
import seaborn as sns
# reconvertir ax en dataFrame pour remettre les nom de cuisine
ax = sns.heatmap(W)
ax.pivot = util_df

# %%
print(H)
print(len(H), len(H[0]))
# Out:
# [[ 0.0413363   0.32009222  0.         ...  0.         13.75283058
#    0.08286734]
#  [ 0.25745358  0.13136452  0.10461423 ...  0.92043636 12.58249348
#    0.0314914 ]]
# 2 6714
